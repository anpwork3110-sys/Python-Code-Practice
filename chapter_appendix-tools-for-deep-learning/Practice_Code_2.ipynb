# %%
my_string='Hello there its new day'

# %%
list(my_string)
# Out:
# ['H',
#  'e',
#  'l',
#  'l',
#  'o',
#  ' ',
#  't',
#  'h',
#  'e',
#  'r',
#  'e',
#  ' ',
#  'i',
#  't',
#  's',
#  ' ',
#  'n',
#  'e',
#  'w',
#  ' ',
#  'd',
#  'a',
#  'y']

# %%
my_list=my_string.split()

# %%
my_list
# Out:
# ['Hello', 'there', 'its', 'new', 'day']

# %%
my_list[1][2]
# Out:
# 'e'

# %%
my_list2=list(my_string)

# %%
my_list2[3]
# Out:
# 'l'

# %%
my_string[::-1]
# Out:
# 'yad wen sti ereht olleH'

# %%
print('this is good morning \n Thank You')
# Out:
# this is good morning
#  Thank You

# %%
print('I Am from India \t It is great country')
# Out:
# I Am from India 	 It is great country

# %%
('-').join(my_string)
# Out:
# 'H-e-l-l-o- -t-h-e-r-e- -i-t-s- -n-e-w- -d-a-y'

# %%
type(my_list2)
# Out:
# list

# %%
my_list*3
# Out:
# ['Hello',
#  'there',
#  'its',
#  'new',
#  'day',
#  'Hello',
#  'there',
#  'its',
#  'new',
#  'day',
#  'Hello',
#  'there',
#  'its',
#  'new',
#  'day']

# %%
my_list1=['asdd']

# %%
my_list + my_list1
# Out:
# ['Hello', 'there', 'its', 'new', 'day', 'asdd']

# %%
print('My Name is {}'.format('Sam'))
# Out:
# My Name is Sam

# %%
name='Jane'
print('Hello {}'.format(name))
# Out:
# Hello Jane

# %%
print(f'hi {name}')
# Out:
# hi Jane

# %%
my_list[0]='Hi'

# %%
my_list.append('Thanks')

# %%
new_list=[1,45,32,56,23]

# %%
new_list.sort()
new_list
my_list.reverse()
my_list
# Out:
# ['Thanks', 'day', 'new', 'its', 'there', 'Hi']

# %%
my_list.reverse()

# %%
my_list.remove('Thanks')

# %%
my_list.remove(my_list[4])

# %%
my_list
# Out:
# ['Hi', 'there', 'its', 'new']

# %%
dict_new={'Fruit':['Apple','Chikoo','Mango','Jack Fruit'],'Vegitable':'Toamto','ID':123}

# %%
dict_new.keys()
# Out:
# dict_keys(['Fruit', 'Vegitable', 'ID'])

# %%
new_tuple=(1,23,445,987,['Hello',123.45],23)

# %%
new_tuple.count(23)
# Out:
# 2

# %%
myset={1,22,22,34,56}

# %%
myset.add(234)
myset
# Out:
# {1, 22, 34, 56, 234}

# %%
string_ip='Mumbai'
newset=set(string_ip)

# %%
newset.pop()
newset
# Out:
# {'M', 'a', 'b', 'i', 'u'}

# %%
string_2='Pune'
newset2=set(string_2)
newset2.pop()
newset2
newset2.pop()
newset2.add('P')
list2=[12,34,56,89,123.789]
newset_list=set(list2)
newset_list
# Out:
# {12, 34, 56, 89, 123.789}

# %%
'Hello'== 'hello'
# Out:
# False

# %%
not'Hi'=='hi'
# Out:
# True

# %%
a=int(input('Please give number:='))
if a%2== 0:
  print('{} is even number'.format(a))
else:
  print('{} is odd number'.format(a))
# Out:
# Please give number:=34
# 34 is even number

# %%
for a,b in {'Apple':34,'Banana':46,'Guava':70}.items():
  if a=='Guava':
    print('Rate of Guava is{}'.format(b))
  else:
    print('Fruit is not Guava')
# Out:
# Fruit is not Guava
# Fruit is not Guava
# Rate of Guava is70

# %%
new_list=[12,23,(1,2,34)]
even_list=[]
for a in new_list:
  if isinstance(a,int):
    if a%2 == 0:
      even_list.append(a)
  elif isinstance(a,tuple):
    for item in a:
      if item%2 ==0:
        even_list.append(item)
even_list
# Out:
# [12, 2, 34]

# %%
tuples_1=((1,'a'),(2,'d'),(3,'m'))
for a,b in tuples_1:
  print (a)
# Out:
# 1
# 2
# 3
