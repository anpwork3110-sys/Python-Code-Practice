# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='https://github.com/anpwork3110-sys/Python-Code-Practice/blob/Practice/Pierian_Data_Logo.png?raw=1'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Statements Assessment Test
# Let's test your knowledge!

# %% [markdown]
# _____
# **Use <code>for</code>, .split(), and <code>if</code> to create a Statement that will print out words that start with 's':**

# %%
st = 'Print only the words that start with s in this sentence'

# %%
#Code here
for word in st.split():
  if word[0]=='s':
    print(word)
# Out:
# start
# s
# sentence

# %% [markdown]
# ______
# **Use range() to print all the even numbers from 0 to 10.**

# %%
#Code Here
for i in list(range(0,10)):
  if i%2==0:
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# ___
# **Use a List Comprehension to create a list of all numbers between 1 and 50 that are divisible by 3.**

# %%
#Code in this cell
list2= [x for x in list(range(1,50)) if x%3==0]
list2
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48]

# %% [markdown]
# _____
# **Go through the string below and if the length of a word is even print "even!"**

# %%
st = 'Print every word in this sentence that has an even number of letters'

# %%
#Code in this cell
list3=st.split()
for word in list3:
  if len(word)%2==0:
    print(word)
# Out:
# word
# in
# this
# sentence
# that
# an
# even
# number
# of

# %% [markdown]
# ____
# **Write a program that prints the integers from 1 to 100. But for multiples of three print "Fizz" instead of the number, and for the multiples of five print "Buzz". For numbers which are multiples of both three and five print "FizzBuzz".**

# %%
#Code in this cell
list4=range(1,101)
for num in list4:
  if num%3 == 0 :
    print('Fizz')
    print(num)
  elif num%5 == 0 :
    print('Buzz')
    print(num)
  elif num%3==0 and num%5==0 :
    print('FixxBuzz')
    print(num)
# Out:
# Fizz
# 3
# Buzz
# 5
# Fizz
# 6
# Fizz
# 9
# Buzz
# 10
# Fizz
# 12
# Fizz
# 15
# Fizz
# 18
# Buzz
# 20
# Fizz
# 21
# Fizz
# 24
# Buzz
# 25
# Fizz
# 27
# Fizz
# 30
# Fizz
# 33
# Buzz
# 35
# Fizz
# 36
# Fizz
# 39
# Buzz
# 40
# Fizz
# 42
# Fizz
# 45
# Fizz
# 48
# Buzz
# 50
# Fizz
# 51
# Fizz
# 54
# Buzz
# 55
# Fizz
# 57
# Fizz
# 60
# Fizz
# 63
# Buzz
# 65
# Fizz
# 66
# Fizz
# 69
# Buzz
# 70
# Fizz
# 72
# Fizz
# 75
# Fizz
# 78
# Buzz
# 80
# Fizz
# 81
# Fizz
# 84
# Buzz
# 85
# Fizz
# 87
# Fizz
# 90
# Fizz
# 93
# Buzz
# 95
# Fizz
# 96
# Fizz
# 99
# Buzz
# 100

# %% [markdown]
# ____
# **Use List Comprehension to create a list of the first letters of every word in the string below:**

# %%
st = 'Create a list of the first letters of every word in this string'

# %%
#Code in this cell
list5=[word[0] for word in st.split()]
list5
# Out:
# ['C', 'a', 'l', 'o', 't', 'f', 'l', 'o', 'e', 'w', 'i', 't', 's']

# %% [markdown]
# ### Great Job!
