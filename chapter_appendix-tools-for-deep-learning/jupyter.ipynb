# %%
1+1
# Out:
# 2

# %% [markdown]
# Mod or Module operator

# %%
4%3
# Out:
# 1

# %%
4/3
# Out:
# 1.3333333333333333

# %% [markdown]
# how to give raise operator to number

# %%
2**2
# Out:
# 4

# %%
3**4
# Out:
# 81
